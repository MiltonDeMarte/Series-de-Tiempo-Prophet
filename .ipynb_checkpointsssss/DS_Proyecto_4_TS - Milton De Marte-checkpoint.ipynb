# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Proyecto-4-/-Series-de-Tiempo-(Utilizando-Prophet-y-LSTM)" data-toc-modified-id="Proyecto-4-/-Series-de-Tiempo-(Utilizando-Prophet-y-LSTM)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Proyecto 4 / Series de Tiempo (Utilizando Prophet y LSTM)</strong></a></span><ul class="toc-item"><li><span><a href="#Metodologia-de-trabajo" data-toc-modified-id="Metodologia-de-trabajo-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><strong>Metodologia de trabajo</strong></a></span></li><li><span><a href="#Pre-procesamiento-2017-2018-2019" data-toc-modified-id="Pre-procesamiento-2017-2018-2019-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span><strong>Pre-procesamiento 2017-2018-2019</strong></a></span><ul class="toc-item"><li><span><a href="#Interpolando-Valores-Atipicos" data-toc-modified-id="Interpolando-Valores-Atipicos-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span><em>Interpolando Valores Atipicos</em></a></span></li><li><span><a href="#Identificando-Valores-Faltantes" data-toc-modified-id="Identificando-Valores-Faltantes-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span><em>Identificando Valores Faltantes</em></a></span></li></ul></li><li><span><a href="#S.A.R.I.M.A.X" data-toc-modified-id="S.A.R.I.M.A.X-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span><strong>S.A.R.I.M.A.X</strong></a></span><ul class="toc-item"><li><span><a href="#Prediccion-4to-Trimestre-2019" data-toc-modified-id="Prediccion-4to-Trimestre-2019-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span><em>Prediccion 4to Trimestre 2019</em></a></span></li><li><span><a href="#Prediccion---2020-(Benchmark)" data-toc-modified-id="Prediccion---2020-(Benchmark)-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span><em>Prediccion - 2020 (Benchmark)</em></a></span></li></ul></li><li><span><a href="#E.D.A-y-Pre-procesamiento-2020" data-toc-modified-id="E.D.A-y-Pre-procesamiento-2020-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span><strong>E.D.A y Pre-procesamiento 2020</strong></a></span><ul class="toc-item"><li><span><a href="#Primeras-Observaciones" data-toc-modified-id="Primeras-Observaciones-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span><em>Primeras Observaciones</em></a></span></li><li><span><a href="#Interpolando-Valores-Atipicos" data-toc-modified-id="Interpolando-Valores-Atipicos-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span><em>Interpolando Valores Atipicos</em></a></span><ul class="toc-item"><li><span><a href="#Distintos-metodos-de-interpolacion" data-toc-modified-id="Distintos-metodos-de-interpolacion-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span><em>Distintos metodos de interpolacion</em></a></span></li></ul></li><li><span><a href="#Resampleando-a-Frecuencia-Semanal" data-toc-modified-id="Resampleando-a-Frecuencia-Semanal-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span><em>Resampleando a Frecuencia Semanal</em></a></span></li></ul></li><li><span><a href="#Benchmark-Model" data-toc-modified-id="Benchmark-Model-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span><strong>Benchmark Model</strong></a></span><ul class="toc-item"><li><span><a href="#Prediccion" data-toc-modified-id="Prediccion-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span><em>Prediccion</em></a></span></li><li><span><a href="#Emparejamiento-de-fechas" data-toc-modified-id="Emparejamiento-de-fechas-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span><em>Emparejamiento de fechas</em></a></span></li><li><span><a href="#Graficando-y-Evaluando" data-toc-modified-id="Graficando-y-Evaluando-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span><em>Graficando y Evaluando</em></a></span></li></ul></li><li><span><a href="#Prophet" data-toc-modified-id="Prophet-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span><strong>Prophet</strong></a></span><ul class="toc-item"><li><span><a href="#Prediciendo:-4to-Trimestre-2019-/-Año-2020" data-toc-modified-id="Prediciendo:-4to-Trimestre-2019-/-Año-2020-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Prediciendo: 4to Trimestre 2019 / Año 2020</a></span></li><li><span><a href="#Prediccion:-4to-trimestre-2019" data-toc-modified-id="Prediccion:-4to-trimestre-2019-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Prediccion: 4to trimestre 2019</a></span><ul class="toc-item"><li><span><a href="#Graficando-y-Evaluando" data-toc-modified-id="Graficando-y-Evaluando-1.6.2.1"><span class="toc-item-num">1.6.2.1&nbsp;&nbsp;</span><em>Graficando y Evaluando</em></a></span></li></ul></li><li><span><a href="#Hypertunning" data-toc-modified-id="Hypertunning-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Hypertunning</a></span><ul class="toc-item"><li><span><a href="#Combinaciones-de--Parametros-1" data-toc-modified-id="Combinaciones-de--Parametros-1-1.6.3.1"><span class="toc-item-num">1.6.3.1&nbsp;&nbsp;</span><em>Combinaciones de  Parametros 1</em></a></span></li><li><span><a href="#Re-entrenando/Evaluando-modelo_1" data-toc-modified-id="Re-entrenando/Evaluando-modelo_1-1.6.3.2"><span class="toc-item-num">1.6.3.2&nbsp;&nbsp;</span><em>Re-entrenando/Evaluando modelo_1</em></a></span></li><li><span><a href="#Re-entrenando/Evaluando-modelo_2" data-toc-modified-id="Re-entrenando/Evaluando-modelo_2-1.6.3.3"><span class="toc-item-num">1.6.3.3&nbsp;&nbsp;</span><em>Re-entrenando/Evaluando modelo_2</em></a></span></li><li><span><a href="#Combinaciones-de-Parametros-2" data-toc-modified-id="Combinaciones-de-Parametros-2-1.6.3.4"><span class="toc-item-num">1.6.3.4&nbsp;&nbsp;</span><em>Combinaciones de Parametros 2</em></a></span></li><li><span><a href="#Re-entrando/Evaluando-modelo" data-toc-modified-id="Re-entrando/Evaluando-modelo-1.6.3.5"><span class="toc-item-num">1.6.3.5&nbsp;&nbsp;</span><em>Re-entrando/Evaluando modelo</em></a></span></li><li><span><a href="#Combinaciones-de-Prametros-3" data-toc-modified-id="Combinaciones-de-Prametros-3-1.6.3.6"><span class="toc-item-num">1.6.3.6&nbsp;&nbsp;</span><em>Combinaciones de Prametros 3</em></a></span></li><li><span><a href="#Re-entrando/Evaluando-modelo" data-toc-modified-id="Re-entrando/Evaluando-modelo-1.6.3.7"><span class="toc-item-num">1.6.3.7&nbsp;&nbsp;</span><em>Re-entrando/Evaluando modelo</em></a></span></li></ul></li><li><span><a href="#Prediccion-:-Año-2020" data-toc-modified-id="Prediccion-:-Año-2020-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>Prediccion : Año 2020</a></span><ul class="toc-item"><li><span><a href="#Prophet-default-pred" data-toc-modified-id="Prophet-default-pred-1.6.4.1"><span class="toc-item-num">1.6.4.1&nbsp;&nbsp;</span><em>Prophet-default pred</em></a></span></li><li><span><a href="#Prophet-tunned-pred" data-toc-modified-id="Prophet-tunned-pred-1.6.4.2"><span class="toc-item-num">1.6.4.2&nbsp;&nbsp;</span><em>Prophet-tunned pred</em></a></span></li><li><span><a href="#Prophet-tunned-pred-2" data-toc-modified-id="Prophet-tunned-pred-2-1.6.4.3"><span class="toc-item-num">1.6.4.3&nbsp;&nbsp;</span><em>Prophet-tunned pred 2</em></a></span></li><li><span><a href="#Graficando-y-Evaluando" data-toc-modified-id="Graficando-y-Evaluando-1.6.4.4"><span class="toc-item-num">1.6.4.4&nbsp;&nbsp;</span><em>Graficando y Evaluando</em></a></span></li></ul></li></ul></li><li><span><a href="#Conclusiones-Finales:" data-toc-modified-id="Conclusiones-Finales:-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span><strong>Conclusiones Finales:</strong></a></span></li></ul></li></ul></div>

# %% [markdown]
# # **Proyecto 4 / Series de Tiempo (Utilizando Prophet y LSTM)**

# %% [markdown]
# ##### **INFORMACION IMPORTANTE ANTES DE SEGUIR**
#
#
# * _*El Proyecto que esta viendo es una simplificacion **ENORME** del proyecto anterior ([Proyecto 3 - Modelos Avanzados](https://github.com/MiltonDeMarte/Series-de-Tiempo.git)).*_
#
#
# * _*Dado que el trabajo planteado para este proyecto es: Probar nuevos modelos(no vistos en clase) **o** agregar nuevas variables predictoras y/o nueva informacion(en este caso agregar años pasados observados a la "formula") **o** profundizar la E.D.A **o** todas si es que se puede, emplee una simplificacion de todo lo trabajado en el proyecto pasado para dejar aqui solo lo necesario para que este proyecto pueda ser llevado acabo.*_
#
#
# * _*Es **muy** probable que, si no a visto el proyecto pasado, encuentre todo lo hecho en este NB muy "lineal". Eso se debe a que: Toda la informacion, implementaciones, justificaciones y conclusiones necesarias para entender el porque de lo que se esta haciendo fue todo llevado acabo y sumamente explicado en gran extension en el proyecto anterior. Es por esto que es **fundamental**, de no haberlo echo, leer el [Proyecto 3](https://github.com/MiltonDeMarte/Series-de-Tiempo.git).*_
#
# *A continuacion enumerare mi metodologia de trabajo pero no antes sin destacar la importancia TOTAL de acceder a los links provistos arriba y descargar todo lo necesario para continuar con la lectura de este Notebook. ([GitHub Profile](https://github.com/MiltonDeMarte) & [GitHub Repository](https://github.com/MiltonDeMarte?tab=repositories))*
#
#
# **Links**
#
# * En los accesos proporcionados se encontrara lo necesario para "ponerse al dia" con este Notebook(tanto la informacion como los archivos necesarios). En el siguiente repositorio se encontraran los datos necesarios para llevar acabo la ejecucion del siguiente proyecto(a diferencia del Proyecto 3, en este se incluyen los datos del año 2020)
#
#
# * [GitHub Repository-Proyecto 4](https://github.com/MiltonDeMarte/Series-de-Tiempo-Prophet). Contiene un nuevo archivo csv llamado *flujo-vehicular-2020* en formar RAR debido a su peso. Es **muy importante** realizar un *pull* a este repositorio y descomprimir el archivo RAR(de lo contrario, llegada a la instancia **EDA-2020** no se encontrara el archivo y devovlera error el codigo).

# %% [markdown]
# ## **Metodologia de trabajo**
#
# Para este proyecto se utilizara todo lo trabajado en el Proyecto 3 dejando solo en el NB lo necesario para correr los nuevos modelos y que sean comparados con los resultados del mejor modelo del proyecto 3(S.A.R.I.M.A.X). Para esto pretendo:
#
# * _*Descargar los datos proporcionados por AUSA sobre las autopistas de este año(2020). Realizar el pre-procesamiento necesario de los mismos y, dado que ya tengo los datos (hasta Octubre) sobre el año 2020, utilizar la prediccion de SARIMAX sobre el mismo año como modelo Benchmark. Observar cual es su resultado RMSE y como el mismo desemepeña sobre los datos reales.*_
#
#
# * _*Utilizar el modelo **Prophet** de Facebook para entrenarlo sobre los datos ya pre-procesados y contrastar sus resultados con el modelo predilecto del Proyecto 3(SARIMAX prediccion 4to trimestre 2019 / prediccion 2020 - Benchmark).*_
#
#
#
# * _*Luego de realizar los pasos anteriores, observar los resultados RMSE de SARIMAX y Prophet para elegir (tanto en RMSE como en el grafico) cual es el mejor modelo.*_
#
#
#
# * **Aclaracion importante:**
#
# >  _*Dado que ya se conoce, a grandes rasgos, cual va a ser el registro de la autopista Illia(forma de pago EFECTIVO) no creo que agregarle mas informacion al Dataset trabajado genere mejores resultados. ¿Que quiero decir? Por la investigacion previa realizada en el Proyecto 3(tanto por dentro como por fuera del mismo), sabemos que la Autopista Illia con el pasar de los años registra considerablemente menos vehiculos (ya sea por hora, dia, semana, etc) que otras autopistas o en su defecto, que la misma autopista pero con otras formas de pago(Telepase siendo la que predomina por sobre el resto). Entonces, si ya se observa como con el pasar de los años la forma de pago EFECTIVO desciende considerablemente y al mismo tiempo la autopista registra menos vehiculos por la creacion de nuevos accesos que descongestionan un poco el trafico generada por la misma, concluyo que: Al cargarle informacion de años pasados observados al DS, muy probablemente me encuentre con que la autopista Illia registraba mas vehiculos anualmente y probablemente la forma de pago en EFECTIVO generaba un conteo mucho mas elevado que el de los años estudiados. Esto, si bien en una parte puede llegar a ayudar al modelo a que comprenda que al pasar los años el conteo de vehiculos y la forma de pago elegida va a ser menor, creo que no es necesario dado que la investigacion(por fuera del DS mayormente) indica y sostiene como la autopista con el pasar de los años registrara cada vez menos vehiculos y al mismo tiempo estos muy probablemente se registren con forma de pago TELEPASE dado que, a partir del pasado 28 de Septiembre, para ingresar a ciertos sectores de la ciudad es [obligatorio el uso de Telepase](https://www.buenosaires.gob.ar/jefaturadegabinete/movilidad/noticias/por-el-alto-numero-de-adhesiones-diarias-habra-tiempo-hasta-el). Por estas razones concluyo porque no agregare informacion de observaciones pasadas al DS para resolver la problematica planteada.*_

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

import seaborn as sns
import sklearn.metrics as metrics
import matplotlib.gridspec as gs
import statsmodels.tsa as tsa
import statsmodels.api as sm

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa import stattools
from fbprophet import Prophet
from sklearn.model_selection import TimeSeriesSplit
from fbprophet.diagnostics import cross_validation, performance_metrics
from joblib import Parallel, delayed

import warnings, itertools
warnings.filterwarnings("ignore")

sns.set(style='darkgrid')

# %% [markdown]
# ## **Pre-procesamiento 2017-2018-2019**

# %%
data_2019 = pd.read_csv('Datasets/flujo-vehicular-2019.csv', sep =',')
data_2018 = pd.read_csv('Datasets/flujo-vehicular-2018.csv', sep =',')
data_2017 = pd.read_csv('Datasets/flujo-vehicular-2017.csv', sep =',')

# %%
dataset = pd.concat([data_2019, data_2018, data_2017])


mask = np.logical_and(dataset.estacion=='Illia', dataset.forma_pago == 'EFECTIVO')
dataset = dataset[mask]

dataset.drop(columns = ['periodo','hora_inicio','forma_pago', 'estacion'], inplace = True)

dataset.head()
# Out:
#           fecha  hora_fin     dia    sentido tipo_vehiculo  cantidad_pasos
# 80   2019-01-01         2  Martes     Centro       Liviano             537
# 86   2019-01-01         2  Martes     Centro        Pesado               1
# 88   2019-01-01         2  Martes  Provincia       Liviano             443
# 94   2019-01-01         2  Martes  Provincia        Pesado               1
# 149  2019-01-01         3  Martes     Centro       Liviano             769

# %%
dataset['fecha2'] = pd.to_datetime(dataset.fecha) + pd.to_timedelta(dataset.hora_fin, unit = 'h')

dataset.drop(columns=['fecha','hora_fin'], inplace = True)

dataset.head()
# Out:
#         dia    sentido tipo_vehiculo  cantidad_pasos              fecha2
# 80   Martes     Centro       Liviano             537 2019-01-01 02:00:00
# 86   Martes     Centro        Pesado               1 2019-01-01 02:00:00
# 88   Martes  Provincia       Liviano             443 2019-01-01 02:00:00
# 94   Martes  Provincia        Pesado               1 2019-01-01 02:00:00
# 149  Martes     Centro       Liviano             769 2019-01-01 03:00:00

# %%
dataset.rename(columns = {'fecha2':'fecha', "cantidad_pasos":"cantidad_autos"}, inplace = True) 
dataset.head()
# Out:
#         dia    sentido tipo_vehiculo  cantidad_autos               fecha
# 80   Martes     Centro       Liviano             537 2019-01-01 02:00:00
# 86   Martes     Centro        Pesado               1 2019-01-01 02:00:00
# 88   Martes  Provincia       Liviano             443 2019-01-01 02:00:00
# 94   Martes  Provincia        Pesado               1 2019-01-01 02:00:00
# 149  Martes     Centro       Liviano             769 2019-01-01 03:00:00

# %%
dataset.sort_values('fecha', inplace = True)
dataset.reset_index(drop=True, inplace = True)
dataset.head()
dataset.shape
# Out:
# (238869, 5)

# %%
dataset.describe()
# Out:
#        cantidad_autos
# count   238869.000000
# mean       200.384232
# std        403.246904
# min          1.000000
# 25%          2.000000
# 50%         11.000000
# 75%        104.000000
# max       2416.000000

# %%
plt.figure(figsize = (15,6))
plt.plot(dataset.fecha, dataset.cantidad_autos)
plt.title("Flujo de autos medido en Horas \n", color= 'r', fontsize= 15)
plt.xlabel('\n Tiempo', color= 'g', fontsize= 15)
plt.ylabel('\n Cantidad de autos, por hora', color= 'g', fontsize= 15)
plt.show()

# %%
diario = dataset.resample('D', on = 'fecha').sum()
print(diario.shape)
diario.head()
# Out:
# (1095, 1)
#             cantidad_autos
# fecha
# 2017-01-01           31183
# 2017-01-02           51568
# 2017-01-03           51093
# 2017-01-04           53332
# 2017-01-05           56486

# %%
diario.describe()
# Out:
#        cantidad_autos
# count     1095.000000
# mean     43712.859361
# std       8192.736927
# min          0.000000
# 25%      39061.500000
# 50%      43761.000000
# 75%      49498.000000
# max      63127.000000

# %%
plt.figure(figsize = (15,6))

plt.plot(diario.index, diario.cantidad_autos)
plt.title("Flujo de autos medido en Dias \n", color= 'r', fontsize= 15)
plt.xlabel('\n Tiempo', color= 'g', fontsize= 15)
plt.ylabel('\n Cantidad de autos, por dia', color= 'g', fontsize= 15)

plt.show()

# %% [markdown]
# ### *Interpolando Valores Atipicos*

# %%
diario[(diario.cantidad_autos == 0) | (diario.cantidad_autos <= 10000)] = np.NaN

print(diario.shape)

print(diario.isna().sum())

diario= diario.interpolate(method='nearest', k=4)

print(diario.isna().sum())
# Out:
# (1095, 1)
# cantidad_autos    6
# dtype: int64
# cantidad_autos    0
# dtype: int64

# %%
plt.figure(figsize = (15,6))

plt.plot(diario.index, diario.cantidad_autos,  color= "crimson")
plt.title("Flujo de vehiculos frecuencia Diaria (sin Valores Atipicos)", color= 'indianred', fontsize= 20)
plt.xlabel('\n Tiempo', color= 'indigo', fontsize= 15)
plt.ylabel('\n Cantidad de autos, por dia', color= 'indigo', fontsize= 15, loc='top', rotation=0)
plt.ylim((0,80000))

plt.show()

# %% [markdown]
# ### *Identificando Valores Faltantes*

# %%
semanal= diario.resample("W").sum()

# %%
semanal= diario.resample("W").mean()

# %%
semanal.index.to_series().diff().value_counts()
# Out:
# 7 days    157
# Name: fecha, dtype: int64

# %% [markdown]
# * _*Como ya se demostro y explico en el [proyecto anterior](https://github.com/MiltonDeMarte/Series-de-Tiempo.git), no hay Valores Faltantes en la serie observada.*_

# %% [markdown]
# *Por practicidad, para luego sea comparado con los modelos, voy a instanciar el ultimo trimestre del año 2019*

# %%
ult_tri_2019 = semanal[(semanal.index >= "2019-10-06") & (semanal.index <= "2019-12-29")]

ult_tri_2019
# Out:
#             cantidad_autos
# fecha
# 2019-10-06    38926.142857
# 2019-10-13    37262.857143
# 2019-10-20    38163.857143
# 2019-10-27    37564.285714
# 2019-11-03    39018.428571
# 2019-11-10    38648.000000
# 2019-11-17    40255.714286
# 2019-11-24    37785.714286
# 2019-12-01    38079.285714
# 2019-12-08    40413.000000
# 2019-12-15    38994.285714
# 2019-12-22    41840.142857
# 2019-12-29    32341.428571

# %% [markdown]
# ## **S.A.R.I.M.A.X**

# %%
y= semanal.cantidad_autos


model= sm.tsa.statespace.SARIMAX(y,
                                order=(10, 1, 8),
                                seasonal_order=(10, 1, 8, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results= model.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0360     61.076     -0.001      1.000    -119.742     119.670
# ar.L2          0.0683     81.958      0.001      0.999    -160.566     160.703
# ar.L3         -0.0024     26.397  -8.92e-05      1.000     -51.739      51.734
# ar.L4         -0.1821     36.657     -0.005      0.996     -72.029      71.665
# ar.L5         -0.0520     26.341     -0.002      0.998     -51.680      51.576
# ar.L6         -0.4595     25.959     -0.018      0.986     -51.339      50.420
# ar.L7         -0.2923     26.823     -0.011      0.991     -52.864      52.279
# ar.L8          0.5283     57.696      0.009      0.993    -112.554     113.611
# ar.L9          0.5173     96.690      0.005      0.996    -188.992     190.026
# ar.L10         0.1030     40.571      0.003      0.998     -79.415      79.621
# ma.L1          0.3604     46.498      0.008      0.994     -90.775      91.495
# ma.L2          0.2093     56.451      0.004      0.997    -110.432     110.851
# ma.L3          0.2067     53.735      0.004      0.997    -105.112     105.525
# ma.L4         -0.1380     35.109     -0.004      0.997     -68.951      68.674
# ma.L5         -0.1057     45.195     -0.002      0.998     -88.687      88.475
# ma.L6          0.1336     42.992      0.003      0.998     -84.129      84.396
# ma.L7          0.0181     43.573      0.000      1.000     -85.383      85.419
# ma.L8         -0.0584     15.900     -0.004      0.997     -31.222      31.105
# ar.S.L12       0.1331     17.397      0.008      0.994     -33.964      34.230
# ar.S.L24       0.0869     21.180      0.004      0.997     -41.426      41.600
# ar.S.L36      -0.0413     55.855     -0.001      0.999    -109.515     109.432
# ar.S.L48      -0.3997     27.991     -0.014      0.989     -55.262      54.463
# ar.S.L60       0.4972     62.147      0.008      0.994    -121.308     122.302
# ar.S.L72       0.2515     71.600      0.004      0.997    -140.081     140.584
# ar.S.L84       0.4276     40.113      0.011      0.991     -78.192      79.047
# ar.S.L96       0.0284     33.816      0.001      0.999     -66.250      66.307
# ar.S.L108     -0.3531     20.592     -0.017      0.986     -40.712      40.006
# ar.S.L120     -0.1288     34.784     -0.004      0.997     -68.303      68.046
# ma.S.L12       0.0209     18.972      0.001      0.999     -37.163      37.205
# ma.S.L24       0.0278     13.943      0.002      0.998     -27.300      27.356
# ma.S.L36       0.0273     57.467      0.000      1.000    -112.607     112.661
# ma.S.L48      -0.0164     21.697     -0.001      0.999     -42.541      42.509
# ma.S.L60      -0.0148     16.574     -0.001      0.999     -32.499      32.470
# ma.S.L72       0.0294     77.715      0.000      1.000    -152.289     152.348
# ma.S.L84      -0.0060     33.083     -0.000      1.000     -64.848      64.836
# ma.S.L96       0.0305     84.186      0.000      1.000    -164.972     165.033
# sigma2      1.327e+07      0.002   6.87e+09      0.000    1.33e+07    1.33e+07
# ==============================================================================

# %% [markdown]
# ### *Prediccion 4to Trimestre 2019*

# %% [markdown]
# * _*Vuelvo a generar la prediccion de SARIMAX para el ultimo trimestre del año 2019 para luego, comparar con la prediccion de Prophet sobre el mismo tiempo observado. Confrontar los resultados y observar si el nuevo modelo presenta mejoras sustanciables para con SARIMAX.*_
#
#
# **Observacion personal:**
#
# * _*Por mi parte lo veo "dificil" que los nuevos modelos mejoren la prediccion de SARIMAX para el ultimo trimestre de 2019. El mismo devolvio, no solo una gran interpretacion y adaptacion a los valores de la serie sino tambien, un excelente resultado luego de ser evaluado a traves de la metrica elegida(RMSE). Se esperan obtener mejores resultados aunque se anticipa la no-obtencion de los mismos. Continuo con la observacion a lo largo del trabajo.*_

# %%
prediction = results.get_prediction(start= dt.datetime(2019,10,6), dynamic=False)
pred_conf = prediction.conf_int()

plt.figure(figsize=(20,10))

ax = y['2017':].plot(label='Serie Observada')
prediction.predicted_mean.plot(ax=ax, label='SARIMAX One-Step-Prediction', alpha=0.7)

ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='k', alpha=0.2)

plt.title("Desempeño SARIMAX One-Step Trimestre-2019", color= 'k', fontsize=25)
ax.set_xlabel("\n Fecha", fontsize=18, color='indigo')
ax.set_ylabel("\n  Cantidad Autos", loc= 'top', rotation=0, fontsize=18,color='indigo')
plt.xlim(dt.datetime(2019,1,1), dt.datetime(2019,12,29))
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)

plt.legend(fontsize=15)
plt.show()

y_forecast= prediction.predicted_mean
y_real = y['2019-10-06':]


rmse_sarimax_one = np.sqrt(metrics.mean_squared_error(y_forecast, y_real))
print("RMSE- SARIMAX: ", rmse_sarimax_one)
# Out:
# RMSE- SARIMAX:  67.08190224279655

# %% [markdown]
# * _*Por practicidad, dejo instanciando en un nuevo objeto la prediccion de SARIMAX para el ultimo trimestre del año 2019.*_

# %%
prediction = results.get_prediction(start= dt.datetime(2019,10,6), dynamic=False)
sarimax_pred_2019= prediction.predicted_mean

sarimax_pred_2019 = pd.DataFrame(sarimax_pred_2019)

sarimax_pred_2019.rename(columns={"predicted_mean":'cantidad_autos'}, inplace=True)

sarimax_pred_2019.drop(index= dt.datetime(2020,1,5), inplace=True)

sarimax_pred_2019 = sarimax_pred_2019.set_index(sarimax_pred_2019.index)

sarimax_pred_2019
# Out:
#             cantidad_autos
# fecha
# 2019-10-06    38927.637124
# 2019-10-13    37250.277126
# 2019-10-20    38106.956833
# 2019-10-27    37458.668580
# 2019-11-03    38966.640854
# 2019-11-10    38675.530169
# 2019-11-17    40303.209129
# 2019-11-24    37851.282770
# 2019-12-01    38119.567973
# 2019-12-08    40488.505656
# 2019-12-15    39029.078114
# 2019-12-22    42004.068510
# 2019-12-29    32350.191967

# %% [markdown]
# ### *Prediccion - 2020 (Benchmark)*

# %%
plt.figure(figsize=(20,10))

pred_2020 = results.get_forecast(steps= dt.datetime(2020,12,31))
pred_2020_conf = pred_2020.conf_int()

ax = y.plot(label='Serie Observada')
pred_2020.predicted_mean.plot(ax=ax, label='Prediccion 2020')

ax.fill_between(pred_2020_conf.index,
                pred_2020_conf.iloc[:, 0],
                pred_2020_conf.iloc[:, 1], color='k')

plt.title("Prediccion SARIMAX Año-2020", color= 'k', fontsize=25)
ax.set_xlabel('Fecha', fontsize=18, color='indigo')
ax.set_ylabel('Cantidad Autos', loc= 'top', rotation=0, fontsize=18,color='indigo')
plt.xlim(dt.datetime(2019,10,6), dt.datetime(2020,12,31)) 
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)


plt.legend(fontsize= 15)
plt.show()

# %% [markdown]
# * _*Hasta aqui se a hecho lo necesario para: Tener los datos necesarios para que el modelo SARIMAX pueda generar la prediccion del ultimo trimestre del año 2019 y la prediccion para el año 2020 que fue generada en el proyecto anterior.*_
#
#
# **A continuacion:**
#
#
# * _*El siguiente paso es incoporar al NB los datos del año 2020 para realizar el E.D.A y pre-procesamiento necesario.*_
#
#
# * _*Entrenar el nuevo modelo de Prophet para observar si este contrasta mejores resultados que SARIMAX en la prediccion del 4to trimestre del 2019.*_
#
#
# * _*Luego evaluar que tan buena fue la prediccion de SARIMAX para el año 2020(a travez de RMSE dado que ya poseo los datos reales). De esta manera ya se cuenta con un modelo Benchmark para luego sea confrontado con las predicciones del año 2020 de Prophet.*_

# %% [markdown]
# ## **E.D.A y Pre-procesamiento 2020**

# %% [markdown]
# * _*Continuo con la metodologia del proyecto 3. **E.D.A** y **pre-procesamiento** se realizaran en frecuencia diaria (personalmente la encontre mas facil para explorar) y una ves finalizados, rezampleare a frecuencia semanal.*_

# %%
data_2020 = pd.read_csv('Datasets/flujo-vehicular-2020.csv', sep =',')

# %%
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847933 entries, 0 to 1847932
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   periodo         int64
#  1   fecha           object
#  2   mes             object
#  3   dia             object
#  4   dia_fecha       int64
#  5   hora_inicio     int64
#  6   hora_fin        int64
#  7   estacion        object
#  8   tipo_vehiculo   object
#  9   forma_pago      object
#  10  observacion     object
#  11  sentido         object
#  12  cantidad_pasos  int64
# dtypes: int64(5), object(8)
# memory usage: 183.3+ MB

# %%
data_2020 = data_2020[(data_2020.estacion == "ILLIA") & (data_2020.forma_pago == "Efectivo")]

data_2020.head()
# Out:
#      periodo                fecha    mes        dia  dia_fecha  hora_inicio  \
# 52      2020  2020-01-01 00:00:00  enero  Miércoles          1            0
# 53      2020  2020-01-01 00:00:00  enero  Miércoles          1            0
# 134     2020  2020-01-01 00:00:00  enero  Miércoles          1            1
# 135     2020  2020-01-01 00:00:00  enero  Miércoles          1            1
# 202     2020  2020-01-01 00:00:00  enero  Miércoles          1            2
#
#      hora_fin estacion tipo_vehiculo forma_pago observacion    sentido  \
# 52          1    ILLIA          Auto   Efectivo    Efectivo     Centro
# 53          1    ILLIA          Auto   Efectivo    Efectivo  Provincia
# 134         2    ILLIA          Auto   Efectivo    Efectivo     Centro
# 135         2    ILLIA          Auto   Efectivo    Efectivo  Provincia
# 202         3    ILLIA          Auto   Efectivo    Efectivo     Centro
#
#      cantidad_pasos
# 52              326
# 53              319
# 134             199
# 135             180
# 202             114

# %%
data_2020['fecha2'] = pd.to_datetime(data_2020.fecha) + pd.to_timedelta(data_2020.hora_fin, unit = 'h')

data_2020.drop(columns=['fecha','hora_fin',
                        'periodo','hora_inicio',
                        'forma_pago', 'estacion',
                       'mes','observacion','dia_fecha'], inplace = True)

data_2020.head()
# Out:
#            dia tipo_vehiculo    sentido  cantidad_pasos              fecha2
# 52   Miércoles          Auto     Centro             326 2020-01-01 01:00:00
# 53   Miércoles          Auto  Provincia             319 2020-01-01 01:00:00
# 134  Miércoles          Auto     Centro             199 2020-01-01 02:00:00
# 135  Miércoles          Auto  Provincia             180 2020-01-01 02:00:00
# 202  Miércoles          Auto     Centro             114 2020-01-01 03:00:00

# %%
data_2020.rename(columns = {'fecha2':'fecha', "cantidad_pasos":"cantidad_autos"}, inplace = True) 
data_2020.head()
# Out:
#            dia tipo_vehiculo    sentido  cantidad_autos               fecha
# 52   Miércoles          Auto     Centro             326 2020-01-01 01:00:00
# 53   Miércoles          Auto  Provincia             319 2020-01-01 01:00:00
# 134  Miércoles          Auto     Centro             199 2020-01-01 02:00:00
# 135  Miércoles          Auto  Provincia             180 2020-01-01 02:00:00
# 202  Miércoles          Auto     Centro             114 2020-01-01 03:00:00

# %%
data_2020.sort_values('fecha', inplace = True)
data_2020.reset_index(drop=True, inplace = True)
data_2020.head()
data_2020.shape
# Out:
# (39072, 5)

# %%
data_2020 = data_2020.resample('D', on = 'fecha').sum()
print(data_2020.shape)
data_2020.head()
# Out:
# (274, 1)
#             cantidad_autos
# fecha
# 2020-01-01           21395
# 2020-01-02           33722
# 2020-01-03           37067
# 2020-01-04           30627
# 2020-01-05           27812

# %%
data_2020.tail()
# Out:
#             cantidad_autos
# fecha
# 2020-09-26            5474
# 2020-09-27            3987
# 2020-09-28            5379
# 2020-09-29            5369
# 2020-09-30            5432

# %%
data_2020.describe()
# Out:
#        cantidad_autos
# count      274.000000
# mean     15228.485401
# std      13550.682663
# min          0.000000
# 25%       4171.750000
# 50%      12478.000000
# 75%      28268.750000
# max      45488.000000

# %%
plt.figure(figsize = (15,6))

plt.plot(data_2020.index, data_2020.cantidad_autos)
plt.title("Serie observada - Año 2020", color= 'r', fontsize= 25)
plt.xlabel('\n Tiempo', color= 'g', fontsize= 18)
plt.ylabel('\n Cantidad de autos por dia', loc= 'top', rotation=0, color= 'g', fontsize= 18)

plt.show()

# %% [markdown]
# * Se crea una mascara para observar en profundidad las fechas que se vieron afectadas por este "*fenomeno*".

# %%
mask= data_2020[(data_2020.cantidad_autos == 0) | (data_2020.cantidad_autos < 3000)] # Busqueda manual del 
                                                                                     # segundo valor(3000)

mask
# Out:
#             cantidad_autos
# fecha
# 2020-03-20               0
# 2020-03-21               0
# 2020-03-22               0
# 2020-03-23               0
# 2020-03-24               0
# 2020-03-25               0
# 2020-03-26               0
# 2020-03-27               0
# 2020-03-28               0
# 2020-03-29               0
# 2020-03-30               0
# 2020-03-31               0
# 2020-04-01               0
# 2020-04-02               0
# 2020-04-03               0
# 2020-04-04               0
# 2020-04-05               0
# 2020-04-06               0
# 2020-04-07               0
# 2020-04-08               0
# 2020-04-09               0
# 2020-04-10               0
# 2020-04-11               0
# 2020-04-12               0
# 2020-04-13               0
# 2020-04-14               0
# 2020-04-15               0
# 2020-04-16               0
# 2020-04-17               0
# 2020-04-18               0
# 2020-04-19               0
# 2020-04-20               0
# 2020-04-21               0
# 2020-04-22               0
# 2020-04-23               0
# 2020-04-24               0
# 2020-04-25               0
# 2020-04-26               0
# 2020-04-27               0
# 2020-04-28               0
# 2020-04-29               0
# 2020-04-30               0
# 2020-05-01               0
# 2020-05-02               0
# 2020-05-03               0
# 2020-05-04               0
# 2020-05-05               0
# 2020-05-06               0
# 2020-05-07               0
# 2020-05-08               0
# 2020-05-09               0
# 2020-05-10               0
# 2020-05-11               1
# 2020-05-12               0
# 2020-05-13               0
# 2020-05-14               0
# 2020-05-15               0
# 2020-05-16               0
# 2020-05-17               0
# 2020-05-18               0

# %% [markdown]
# ### *Primeras Observaciones*

# %% [markdown]
# * _*Al realizar el pre-procesamiento necesario del año 2020 para trabajar con los datos de estudio deseados (Autopista **Illia** y forma de pago **Efectivo**) se observa como la representacion grafica de la serie posee un "valor atipico" muy grande, fuertemente marcado y estacionado.*_
#
#
# * _*¿Que paso? Esto no es ninguna sorpresa dado que: Aproximadamente cercano a las fechas en las cuales se registran estos "inicios de descenso" en los registros(en este caso diarios por el resemapleo empleado), **mundialmente**(o en casi todos los paises del mundo) se establecieron cuarentenas muy estrictas(en algunos casos severamente estrictas) para prevenir la esparsion de la nueva enfermedad infecciosa [Covid-19](https://www.who.int/es/emergencies/diseases/novel-coronavirus-2019/advice-for-public/q-a-coronaviruses#:~:text=La%20COVID%2D19%20es,en%20diciembre%20de%202019).*_
#
#   _Este nueva [enfermedad infecciosa](https://www.who.int/topics/infectious_diseases/es/#:~:text=Las%20enfermedades%20infecciosas%20son%20causadas,pueden%20ser%20transmitidas%20al%20hombre.) de rapida esparsion(asi lo describio en sus inicios la OMS) "paralizo" literalmente al mundo. Desde el comercio mas pequeño a la fabrica mas grande se vio afectada por esta pandemia. Al cesar -casi- todo tipo de actividad en los paises, en nuestro caso particular de estudio, las autopistas se vieron completamente afectadas en cuanto al numero de vehiculos que estas registraban al final del ciclo elegido(llamese "ciclo elegido" a la frecuencia empleada para el estudio: horas, dias , semanas, etc)._
#
#   _El pasado [19 de Marzo](https://www.infobae.com/politica/2020/03/20/alberto-fernandez-anuncio-que-la-cuarentena-obligatoria-comienza-esta-medianoche-y-se-extendera-hasta-el-31-de-marzo/) se anuncio en Argentina la imposicion de la cuarentena obligatoria. En la misma se establecio cuales eran los rubros de "extrema necesidad" que podian seguir ejerciendo actividades y cuales no. Al acotar tanto los rubros que podian estar activos, obviamente , el "movimiento" del pais iba a ser considerablemente menor. Todos los tipos de transportes publicos cesaron actividades practicamente y solo [personal exceptuado](https://www.argentina.gob.ar/coronavirus/aislamiento/exceptuados) se vio habilitado a continuar con sus actividades. Al mismo tiempo, dado que las ciudades se encontraban en cuarentena, no habia(generalmente) ningun tipo de necesidad para "ir" a algun lado. Dado esto, es entonces el porque se presenta este registro de 0 vehiculos durante casi 3 meses en la autopista(2020-03-20 / 2020-05-18). Pasado este tiempo de "curentena estricta", se empezaron a implementar nuevas medidas de circulacion ([permisos de circulacion](https://www.argentina.gob.ar/circular?utm_source=search&utm_medium=cpc&utm_campaign=coronavirus&utm_term=grants&utm_content=nacional&gclid=CjwKCAjw0On8BRAgEiwAincsHKlotdBKmB3ewCIP7cR47V7q-zserfr105ivC4pb1ACsNrYfPN44whoC7iMQAvD_BwE)) como al mismo tiempo, el re-incio de actividades de varios rubros tanto [esenciales](https://www.argentina.gob.ar/justicia/derechofacil/leysimple/covid-19-actividades-excluidas-del-aislamiento#titulo-1) como [no-esenciales](https://www.argentina.gob.ar/justicia/derechofacil/leysimple/covid-19-actividades-excluidas-del-aislamiento#titulo-2). Dadas estas nuevas medidas, el pais de a poco volvio a estar en "actividad" contrastandose asi el nuevo registro de vehiculos en la autopista(en este caso Illia) aunque muy acotado a raiz de la curentena pero mas aun,por la forma en la cual se abarcan los datos(*Illia solo Efectivo*)._

# %% [markdown]
# ### *Interpolando Valores Atipicos*

# %% [markdown]
# * _*Si bien una situacion como la del Covid-19 no es algo con lo cual se contaba con que pase este año, son eventos que pueden pasar. Estos eventos "rompen" un poco con las bases que propone el estudio de las series de tiempo las cuales implican que; Para predecir el futuro, asumimos que este se va a comportar de la misma manera(o similar) que el pasado observado y estudiado. Es por esto que, cuando se le pide al modelo entrenado SARIMAX que devuelva la prediccion para el año 2020, se observa una buena interpretacion de los datos dado que capta la "esencia" de la serie para representar valores futuros(la serie predicha es similar a la estudiada, generalmente).*_
#
#
# * _*Antes de interporlar los Valores Atipicos, voy a hacer una comparacion (primera aproximacion benchamrk) sobre la prediccion de SARIMAX para el año 2020 con los dates reales **sin interpolar** los casi 3 meses observados con 0 registros. Luego voy a interpolar estos mismos para observar la nueva representacio de la serie-2020 y re-evaluar a travez de RMSE creando asi el modelo Benchmark final.*_

# %%
#plt.figure(figsize=(20,10))

#pred_2020 = results.get_forecast(steps= dt.datetime(2020,12,31))
#benchmark= pred_2020.predicted_mean

#plt.plot(benchmark, label= 'Prediccion 2020')
#plt.plot(data_2020.index, data_2020.cantidad_autos, label= 'Serie observada (Año 2020)')

#plt.title("Benchmark - Datos observados 2020", color= 'k', fontsize=25)
#plt.xlim(dt.datetime(2020,1,1), dt.datetime(2020,9,30)) 
#plt.ylabel("Cantidad Autos", loc= 'top', rotation= 0, fontsize= 18, color= "indigo")
#plt.xlabel("Fechas", fontsize= 18, color= "indigo")
#plt.yticks(fontsize= 14)
#plt.xticks(fontsize= 14)

#plt.legend(fontsize= 14)
#plt.show()


#y= data_2020.cantidad_autos
#y_real = y['2020-01-01':]


#rmse_benchmark = np.sqrt(metrics.mean_squared_error(benchmark, y))
#print("RMSE- SARIMAX: ", rmse_benchmark)

# %% [markdown]
# **¿Porque la celda de arriba se encuentra TODA comentada?**
#
# * _*Esto se debe a que, al tratar de generar el primer modelo benchmark y evalularlo no se tomo en cuenta que el modelo de SARIMAX, el cual realizo la prediccion del año 2020, fue entrenado en una frecuencia semanal. Por esto motivo es que el codigo arrojaba un error en la cantidad de inputs que posee cada variable (benchmark = 52(freq.semanal) mientras que y = 274(freq.diaria)). Para continuar con el desarrollo del proyecto, se encuentra primordial interpolar los valores atipicos primero para luego resamplear a la frecuencia elegida(semanal) y asi poder evaluar el modelo benchmark sobre los datos reales ya resampleados y curados de Valores Atipicos.*_
#
#
# * _*Dejo la celda con los codigos comentados en caso de querer ejecutarlo y observar la representacion.*_

# %% [markdown]
# #### *Distintos metodos de interpolacion*

# %% [markdown]
# * _*Creo varias copias del DF Diario para probar distintos metodos de interpolacion.*_

# %%
diario0, diario1, diario2, diario3 = data_2020.copy(), data_2020.copy(), data_2020.copy(), data_2020.copy()

# %%
plt.figure(figsize = (15,6))

plt.plot(data_2020.index, data_2020.cantidad_autos)
plt.title("Flujo de autos frecuencia Diaria(con Valores Atipicos)", color= 'indianred', fontsize= 20)
plt.xlabel('\n Tiempo', color= 'indigo', fontsize= 15)
plt.ylabel('\n Cantidad de vehiculos por dia', color= 'indigo', fontsize= 15, loc='top', rotation=0)

plt.show()

# %% [markdown]
# * _*Metodo Linear(deafult)*_

# %%
diario0[(diario0.cantidad_autos == 0) | (diario0.cantidad_autos <= 3000)] = np.NaN

print(diario0.shape)

print(diario0.isna().sum())

diario0= diario0.interpolate()

print(diario0.isna().sum())
# Out:
# (274, 1)
# cantidad_autos    60
# dtype: int64
# cantidad_autos    0
# dtype: int64

# %%
plt.figure(figsize = (15,6))

plt.plot(diario0.index, diario0.cantidad_autos, label= "Linear", color= "grey")
plt.title("Flujo de autos frecuencia Diaria (sin Valores Atipicos)", color= 'indianred', fontsize= 20)
plt.xlabel('\n Tiempo', color= 'indigo', fontsize= 15)
plt.ylabel('\n Cantidad de autos, por dia', color= 'indigo', fontsize= 15, loc='top', rotation=0)
plt.legend(fontsize= 15)

plt.show()

# %% [markdown]
# * _Metodo *'Spline'*_

# %%
diario1[(diario1.cantidad_autos == 0) | (diario1.cantidad_autos <= 3000)] = np.NaN

print(diario1.shape)

print(diario1.isna().sum())

diario1= diario1.interpolate(method='spline', order=2)

print(diario1.isna().sum())
# Out:
# (274, 1)
# cantidad_autos    60
# dtype: int64
# cantidad_autos    0
# dtype: int64

# %%
plt.figure(figsize = (15,6))

plt.plot(diario1.index, diario1.cantidad_autos, label= "Spiline", color= "goldenrod")
plt.title("Flujo de autos frecuencia Diaria (sin Valores Atipicos)", color= 'indianred', fontsize= 20)
plt.xlabel('\n Tiempo', color= 'indigo', fontsize= 15)
plt.ylabel('\n Cantidad de autos, por dia', color= 'indigo', fontsize= 15, loc='top', rotation=0)
plt.legend(fontsize= 15)

plt.show()

# %% [markdown]
# * _*Metodo 'Nearest'*_

# %%
diario2[(diario2.cantidad_autos == 0) | (diario2.cantidad_autos <= 3000)] = np.NaN

print(diario2.shape)

print(diario2.isna().sum())

diario2= diario2.interpolate(method='nearest', k=4)

print(diario2.isna().sum())
# Out:
# (274, 1)
# cantidad_autos    60
# dtype: int64
# cantidad_autos    0
# dtype: int64

# %%
plt.figure(figsize = (15,6))

plt.plot(diario2.index, diario2.cantidad_autos, label= "Nearest", color= "crimson")
plt.title("Flujo de autos frecuencia Diaria (sin Valores Atipicos)", color= 'indianred', fontsize= 20)
plt.xlabel('\n Tiempo', color= 'indigo', fontsize= 15)
plt.ylabel('\n Cantidad de autos, por dia', color= 'indigo', fontsize= 15, loc='top', rotation=0)
plt.legend(fontsize= 15)

plt.show()

# %% [markdown]
# * _*Metodo Time*_

# %%
diario3[(diario3.cantidad_autos == 0) | (diario3.cantidad_autos <= 3000)] = np.NaN

print(diario3.shape)

print(diario3.isna().sum())

diario3= diario3.interpolate(method='nearest', k=4)

print(diario3.isna().sum())
# Out:
# (274, 1)
# cantidad_autos    60
# dtype: int64
# cantidad_autos    0
# dtype: int64

# %%
plt.figure(figsize = (15,6))

plt.plot(diario3.index, diario3.cantidad_autos, label= "Time", color= "indigo")
plt.title("Flujo de autos frecuencia Diaria (sin Valores Atipicos)", color= 'indianred', fontsize= 20)
plt.xlabel('\n Tiempo', color= 'indigo', fontsize= 15)
plt.ylabel('\n Cantidad de autos, por dia', color= 'indigo', fontsize= 15, loc='top', rotation=0)
plt.legend(fontsize= 15)

plt.show()

# %% [markdown]
# **Eligiendo metodo de interpolacion:**
#
# * _*En este caso, al analizar los mismos metodos implementados en el proyecto anterior para interpolar los Valores Atipicos se observa que el metodo `Linear`(default) devuelve la mejor adaptacion.¿Porque? Creo que dado los eventos ocurridos y explicados, este metodo, al contrario de Time y Nearest que se comportan mas linealmente(Spiline directamente no se toma en consideracion por su desempeño), `Linear`traza una recta en descenso para conectar con el proximo valor observado(la pendiente empieza en el ultimo registro de datos y termina cuando se vuelve a registrar trafico en la autopista). Por este motivo continuo trabajando con el objeto "diario0" en el cual los valores atipicos fueron interpolados con ese metodo.*_

# %% [markdown]
# ### *Resampleando a Frecuencia Semanal*

# %%
semanal_2020= diario0.resample("W").sum()

semanal_2020.head()
# Out:
#             cantidad_autos
# fecha
# 2020-01-05        150623.0
# 2020-01-12        243359.0
# 2020-01-19        246818.0
# 2020-01-26        241192.0
# 2020-02-02        253335.0

# %%
semanal_2020= diario0.resample("W").mean()

semanal_2020.head()
# Out:
#             cantidad_autos
# fecha
# 2020-01-05    30124.600000
# 2020-01-12    34765.571429
# 2020-01-19    35259.714286
# 2020-01-26    34456.000000
# 2020-02-02    36190.714286

# %%
semanal_2020.tail()
# Out:
#             cantidad_autos
# fecha
# 2020-09-06    11058.428571
# 2020-09-13    11162.428571
# 2020-09-20     9964.142857
# 2020-09-27     8741.571429
# 2020-10-04     5393.333333

# %% [markdown]
# ## **Benchmark Model**

# %% [markdown]
# ### *Prediccion*

# %%
pred_2020 = results.get_forecast(steps= dt.datetime(2020,12,31))
benchmark= pred_2020.predicted_mean

# %% [markdown]
# ### *Emparejamiento de fechas*
#
# * Se instancia dentro del benchmark las fechas que correspondan a las mismas observadas en el año 2020

# %%
start= "2020-01-01"
end= "2020-10-04"

benchmark= benchmark[(benchmark.index >= start) & (benchmark.index <= end)]

benchmark[dt.datetime(2020,1,5)]= 30124.60000 # Esta es una fecha que por algun motivo el benchmark no contaba con
                                              # es por esta razon que la cree y le inserte el valor real observado de la 
                                              # serie año 2020.

benchmark.index=benchmark.index.sort_values()

benchmark
# Out:
# 2020-01-05    35417.474250
# 2020-01-12    36006.428509
# 2020-01-19    33182.008676
# 2020-01-26    47702.476773
# 2020-02-02    47680.500949
# 2020-02-09    43212.164740
# 2020-02-16    30105.187791
# 2020-02-23    25685.864139
# 2020-03-01    25603.968801
# 2020-03-08    31351.569903
# 2020-03-15    25909.444545
# 2020-03-22    26522.688965
# 2020-03-29    38587.725499
# 2020-04-05    41593.942974
# 2020-04-12    38726.794451
# 2020-04-19    47595.580684
# 2020-04-26    40310.312329
# 2020-05-03    28836.447709
# 2020-05-10    16644.454867
# 2020-05-17    21144.701157
# 2020-05-24    24635.782756
# 2020-05-31    36840.761034
# 2020-06-07    38184.424983
# 2020-06-14    38286.279779
# 2020-06-21    42726.994929
# 2020-06-28    38562.990938
# 2020-07-05    25587.113612
# 2020-07-12    30331.035187
# 2020-07-19    22939.824652
# 2020-07-26    21797.788472
# 2020-08-02    20753.633183
# 2020-08-09    29018.750372
# 2020-08-16    43353.018789
# 2020-08-23    51822.030449
# 2020-08-30    43501.887808
# 2020-09-06    30705.971466
# 2020-09-13    18544.283220
# 2020-09-20    10137.071002
# 2020-09-27     6723.279163
# 2020-10-04    30124.600000
# Name: predicted_mean, dtype: float64

# %% [markdown]
# ### *Graficando y Evaluando*

# %%
plt.figure(figsize=(20,10))

plt.plot(benchmark, label= 'Prediccion 2020')
plt.plot(semanal_2020.index, semanal_2020.cantidad_autos, label= 'Serie observada (Año 2020)')

plt.title("Benchmark - Datos observados 2020", color= 'k', fontsize=25)
plt.xlim(dt.datetime(2020,1,1), dt.datetime(2020,9,30)) 
plt.ylabel("Cantidad Autos", loc= 'top', rotation= 0, fontsize= 18, color= "indigo")
plt.xlabel("Fechas", fontsize= 18, color= "indigo")
plt.yticks(fontsize= 14)
plt.xticks(fontsize= 14)

plt.legend(fontsize= 14)
plt.show()


y= semanal_2020.cantidad_autos

rmse_benchmark = np.sqrt(metrics.mean_squared_error(benchmark, y))
print("RMSE- SARIMAX: ", rmse_benchmark)
# Out:
# RMSE- SARIMAX:  18861.797260273714

# %% [markdown]
# * _*Se observa un desempeño RMSE bastante malo, pero hay que considerar todo el evento pandemico mundial ya explorado y explicado en el E.D.A y pre-procesamiento del año 2020.*_
#
#
# * _*Con los datos ya resampleados, el modelo benchmark entrenado y evaluado procedo a entrenar el nuevo modelo de Prophet, entrenarlo y confrontarlo con las predicciones:*_
#
#     * _S.A.R.I.M.A.X prediccion 4to trimestre año 2019_
#     * _S.A.R.I.M.A.X prediccion año 2020_
#
#
# * _*Observar si este presenta mejoras en sus predicciones en metodo default y luego, a travez de un hypertunnig re-evaluarlo para observar una ves los resultados y confrontar una ultima comparacion con los obtenidos con el modelo SARIMAX.*_

# %% [markdown]
# ## **Prophet**

# %% [markdown]
# **Aclaracion en caso de trabajar con mas features:**
#
#
# *Por lo estudiado e investigado sobre Prophet, el mismo para su implementacion toma solamente 2 parametros: **DS** la cual es la columna que va a contener las fechas observadas e **Y** en la cual se encontraran los valores observados. Consto que Prophet puede volverse un modelo predictor de series de tiempo multivariado utilizando el metodo interno del mimso `add_regressor`.*
#
#
# **Condiciones para trabajar con Prophet:**
#
#
# _*Prophet requiere una condicion bastante simple pero inmutable. Para trabajar con este modelo , hay que renombrar las columnas. La columna con las fechas observadas debe de ser renombrada a **ds** y , la columna con los valores observados debe ser renombrada como **y**. Para poder realizar esto, se utilizara la funcion `reset_index()` para llevar la serie de tiempo a formato DF y asi, poder trabajar de manera mas simple.*_

# %% [markdown]
# ### Prediciendo: 4to Trimestre 2019 / Año 2020

# %% [markdown]
# * _*Creo una copia de la serie.*_

# %%
semanal1 = semanal.copy()

semanal1
# Out:
#             cantidad_autos
# fecha
# 2017-01-01    31183.000000
# 2017-01-08    49601.714286
# 2017-01-15    52344.714286
# 2017-01-22    51030.714286
# 2017-01-29    50654.428571
# ...                    ...
# 2019-12-08    40413.000000
# 2019-12-15    38994.285714
# 2019-12-22    41840.142857
# 2019-12-29    32341.428571
# 2020-01-05    27985.000000
#
# [158 rows x 1 columns]

# %% [markdown]
# * _*Reseteo el indice para volver al formato DataFrame(pudiendo asi cumplir con las condiciones de Prophet).*_

# %%
semanal1 =semanal1.reset_index()

semanal1 = semanal1.rename(columns={'fecha': 'ds',
                                   'cantidad_autos': 'y'})

semanal1
# Out:
#             ds             y
# 0   2017-01-01  31183.000000
# 1   2017-01-08  49601.714286
# 2   2017-01-15  52344.714286
# 3   2017-01-22  51030.714286
# 4   2017-01-29  50654.428571
# ..         ...           ...
# 153 2019-12-08  40413.000000
# 154 2019-12-15  38994.285714
# 155 2019-12-22  41840.142857
# 156 2019-12-29  32341.428571
# 157 2020-01-05  27985.000000
#
# [158 rows x 2 columns]

# %% [markdown]
# * _*Entreno el modelo.*_

# %%
prophet_model= Prophet(interval_width=0.95)

prophet_model.fit(semanal1)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# _Al fijar `interval_width` en 0.95 le "indico" a Prophet que asuma que: El futuro va a seguir comportandose como el pasado(lo cual quedo demostrado en este año -2020- que no es asi)._

# %% [markdown]
# * _*Creo un nuevo DF a partir del modelo entrenado con las la cantidad total de fechas a predecir (todo el año 2020), en este caso : 52 en frecuencia semanal.*_

# %%
prophet_dates = prophet_model.make_future_dataframe(periods=52, freq='W')
prophet_dates.head()
# Out:
#           ds
# 0 2017-01-01
# 1 2017-01-08
# 2 2017-01-15
# 3 2017-01-22
# 4 2017-01-29

# %% [markdown]
# * _*Aqui se pueden ver las ultimas fechas indicadas para construir el DF*_

# %%
prophet_dates.tail()
# Out:
#             ds
# 205 2020-12-06
# 206 2020-12-13
# 207 2020-12-20
# 208 2020-12-27
# 209 2021-01-03

# %% [markdown]
# * _*Ya con el modelo entrenado y el DF creado indico al modelo que : De las fechas creadas(2017 / 2020) prediga un valor para cada una(entre otros features mas que el modelo crea). En este caso, la variable de interes es `yhat`.*_

# %%
prophet_pred = prophet_model.predict(prophet_dates)
prophet_pred[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
#           ds          yhat    yhat_lower    yhat_upper
# 0 2017-01-01  43988.567371  38885.283883  49206.491257
# 1 2017-01-08  43455.664285  38385.722468  48287.483449
# 2 2017-01-15  45676.026504  40860.010338  50684.521519
# 3 2017-01-22  48555.861382  43739.714141  53698.993107
# 4 2017-01-29  50014.340905  45069.271078  55273.153833

# %%
prophet_pred[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 205 2020-12-06  36254.607712  31414.917001  41540.657502
# 206 2020-12-13  36453.327032  30999.893704  42221.435413
# 207 2020-12-20  33978.320211  28433.070837  39766.962241
# 208 2020-12-27  30000.842805  24262.051800  35250.437054
# 209 2021-01-03  27273.422964  22032.217132  32554.253394

# %% [markdown]
# * _*Entonces, hasta aqui con Prophet, entrene el modelo sobre los datos observados de los años 2017/2018/2019 y cree un nuevo DF(**prophet_pred**) con valores predichos(**yhat**) por el modelo para las fechas observadas(**ds**) de los años trabajados. Tambien, en el mismo DF, se incluyen las predicciones de los valores para todo el año 2020(codigo de arriba).*_
#
#
# * _*Siendo asi, solo queda confrontar los resultados de Prophet, SARIMAX y la S.O (serie original) para ver cual de los 2 modelos tuvo mejor desempeño.*_
#
#
# * _Por ultimo, se realizara hypertunning del modelo Prophet para evaluar si el mismo presenta progresos positivos en los resultados luego de las mejoras.*_

# %% [markdown]
# ### Prediccion: 4to trimestre 2019

# %%
prophet_pred_2019 = prophet_pred[(prophet_pred.ds >= "2019-10-06") & (prophet_pred.ds <= "2019-12-29")]

prophet_pred_2019.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)


prophet_pred_2019.rename(columns={'ds':'fecha', "yhat":'cantidad_autos'}, inplace=True)


prophet_pred_2019 = prophet_pred_2019.set_index('fecha')

prophet_pred_2019
# Out:
#             cantidad_autos
# fecha
# 2019-10-06    38576.204764
# 2019-10-13    37837.249593
# 2019-10-20    38129.149862
# 2019-10-27    39438.162519
# 2019-11-03    40469.052167
# 2019-11-10    40071.050462
# 2019-11-17    38689.336248
# 2019-11-24    38003.322250
# 2019-12-01    38962.808341
# 2019-12-08    40438.550209
# 2019-12-15    40193.988159
# 2019-12-22    37291.823838
# 2019-12-29    33328.469636

# %% [markdown]
# * _*Ya creadas las predicciones, fue cuestion de llevarlas a un formato mas amigable:*_
#      * Instanciar las columnas deseadas
#      * Renombrarlas
#      * Transformar el DF a forma TS
#
#
# * _*Concluido estos pasos, procedo a confrontar los datos de Prophet contra SARIMAX y S.O.*_

# %% [markdown]
# #### *Graficando y Evaluando*

# %%
plt.figure(figsize=(20,10))

prophet_model.plot(prophet_pred,
              uncertainty=True);

plt.title("Prophet Full Prediction(2017 / 2020) \n", color= 'k', fontsize=25)
plt.xlabel('\n Fecha', fontsize=18, color='indigo')
plt.ylabel('Cantidad Autos', loc= 'top', rotation=0, fontsize=18,color='indigo')
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)


plt.show()

# %% [markdown]
# _*Aqui se puede observar la prediccion completa de Prophet sobre toda la serie de tiempo.*_
#
#
# * _*Los **puntos negros** representan la **serie observada**.*_
#
#
# * _*La **linea azul** representan los valores predichos por Prophet sobre las fechas entrendas(llegando al final, solo es la linea azul dado que no se contaban con los datos del año 2020)*_
#
#
# * _*Las **regiones sombreadas** representan los intervalos de confianza de la prediccion.*_

# %%
plt.figure(figsize=(20,10))


plt.plot(prophet_pred_2019.index, prophet_pred_2019.cantidad_autos, lw = 2, label= "Prophet - 4to Trimestre-2019")
plt.plot(sarimax_pred_2019.index, sarimax_pred_2019.cantidad_autos, lw = 2.5, label='SARIMAX One-Step-Prediction', alpha=1, color="goldenrod")
plt.plot(ult_tri_2019.index, ult_tri_2019.cantidad_autos,'-.', lw = 4, label='Serie Observada (4to Trimestre 2019)', alpha=0.5, color="darkred")
plt.xlabel("\n Fecha", fontsize=18, color= "indigo")
plt.ylabel("\n Cantidad Autos", fontsize=18, color= "indigo", loc="top", rotation=0)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Prophet / SARIMAX / S.O \n", fontsize=25, color="k")
plt.legend(fontsize=15)


plt.show()


y_forecast_prophet=  prophet_pred_2019.cantidad_autos
y= ult_tri_2019.cantidad_autos

rmse_prophet = np.sqrt(metrics.mean_squared_error(y_forecast_prophet, y))
print("RMSE- Prophet: ", rmse_prophet)
print("RMSE- SARIMAX: ", rmse_sarimax_one)
# Out:
# RMSE- Prophet:  1628.5265639775894
# RMSE- SARIMAX:  67.08190224279655

# %% [markdown]
# * _*Si bien, la prediccion de Prophet es bastante buena , SARIMAX sigue presentando un desempeño superior a la hora de predecir los valores para el ultimo trimestre del año 2019. Quizas, luego del hypertunning para Prophet, el mismo presente progresos positivos en cuanto a los resultados.*_

# %% [markdown]
# ### Hypertunning

# %%
def gs_prophet(params, model, df, cutoffs, rolling_window, horizon):
    '''Brute-Force GridSearch for Prophet models
    Cutoffs must be in -datetime- format
    Rolling-Window must be an int
    Horizon must be denoted as: 'X Y'
         Where X is equal to a number 
               Y is equal to frequency(days or less) - E.G = '30 days' '''
    rmse_list = []  
    for i in params:
        m = model(**i).fit(df) 
        df_cv = cross_validation(m, cutoffs= cutoffs, horizon= horizon, parallel="processes")
        df_p = performance_metrics(df_cv, rolling_window=rolling_window)
        rmse_list.append(df_p['rmse'].values[0])
    tuning_results = pd.DataFrame(params)
    tuning_results['rmse'] = rmse_list
    best_params = params[np.argmin(rmse_list)]
    return tuning_results, tuning_results.loc[tuning_results['rmse'].idxmin()], best_params

# %% [markdown]
# #### *Combinaciones de  Parametros 1*

# %%
param_grid = {  
    'changepoint_prior_scale': [0.001, 0.051, 0.101, 0.151, 0.201,
                                0.251, 0.301, 0.351, 0.401, 0.451,
                                0.501, 0.551, 0.601, 0.651, 0.701,
                                0.751, 0.801, 0.851, 0.901, 0.951,1],
    
    'seasonality_prior_scale': [0.01, 0.51, 1.01, 1.51, 2.01, 2.51,
                                3.01, 3.51, 4.01, 4.51, 5.01, 5.51,
                                6.01, 6.51, 7.01, 7.51, 8.01, 8.51,
                                9.01, 9.51, 10]}

all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

cutoffs = pd.to_datetime(['2017-07-17', '2018-08-19', '2019-10-06'])

# %% [markdown]
# ##### ACLARACION IMPORTANTE
#
# * _*Esta combinaciones de distintos paramaetros para Prophet estuvo corriendo por mas de 1 hora. Si bien no es un impedimiento, recomiendo no correr de nuevo esta celda ni las 2 celdas de codigo posteriores(dado que estan sujetas a esta linea de codigo) para no retrarse en la ejecucion del NB.*_

# %%
gs_prophet(all_params, Prophet, semanal1, cutoffs, 12, '90 days')
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5399D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A854CD0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682AC2340>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A81F070>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A55C40>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682AAFF40>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57CA60>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829C81F0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682AC2E20>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57CFA0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A58C670>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A889460>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A8548E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A74A280>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A6E9A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A86E790>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A82C160>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682AAF040>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A6E9A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A854FA0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A82C160>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A862550>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A74A1F0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57F2E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829C8970>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A582B20>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829C8970>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829C8970>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5A2F10>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5399D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829C8970>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A582B80>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A8620D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A83BD90>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A889070>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829E3400>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A82C160>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A59A250>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5AB670>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A83BD90>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A813790>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829B3490>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A60D00>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A74A370>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A862490>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB765E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7ED3A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A740760>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A86E9A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829E3400>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A813790>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB765E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A740760>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A8548E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57CA60>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57FEE0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829E3430>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A86E790>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A86E9A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57F0D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7C70D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A74A130>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB83B50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5AB670>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A539E50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A86E850>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A539E50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A82C160>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A574B50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57F0D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5AB670>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A86E9D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB83DF0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A574D30>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB76C10>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57C670>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A86E850>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A757DC0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57FA90>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A574D30>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7C7D60>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57FAC0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7C7AC0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB5C3A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7C7D90>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7C7670>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A574250>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7C7070>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A741D30>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB5C9A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB765E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A741820>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A741D60>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57FC40>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A741490>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A574B50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7C7D90>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57F790>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A741100>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A741250>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB68910>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A574190>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7413D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# ...
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB83F70>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A52F760>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A740640>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A578F70>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A854280>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5B0040>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A854130>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A53E130>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A862A00>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5B0130>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A862A00>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A53E130>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB00460>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7C7820>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A740640>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A8628B0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A862640>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A53ED30>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A5B0310>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A847130>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A578B50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A740EE0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A53EFA0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A8A3BB0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7B8E80>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A56CBE0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A52FB50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A83B640>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7B8D30>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB00B20>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A83B040>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A862640>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A7B8E80>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A83B4C0>
# (     changepoint_prior_scale  seasonality_prior_scale          rmse
#  0                      0.001                     0.01  4.419600e+03
#  1                      0.001                     0.51  2.266124e+04
#  2                      0.001                     1.01  2.889825e+04
#  3                      0.001                     1.51  3.747485e+04
#  4                      0.001                     2.01  4.392167e+04
#  ..                       ...                      ...           ...
#  436                    1.000                     8.01  1.777487e+06
#  437                    1.000                     8.51  2.125058e+06
#  438                    1.000                     9.01  1.984397e+06
#  439                    1.000                     9.51  1.899310e+06
#  440                    1.000                    10.00  2.611541e+06
#
#  [441 rows x 3 columns],
#  changepoint_prior_scale       0.601000
#  seasonality_prior_scale       0.010000
#  rmse                       2554.483803
#  Name: 252, dtype: float64,
#  {'changepoint_prior_scale': 0.601, 'seasonality_prior_scale': 0.01})

# %% [markdown]
# * _*Se probaron mas de 400 combinaciones distintas de los parametros `changepoint_prior_scale` y `seasonality_prior_scale` obteniendos asi 441 resultados **rmse** distintos.*_

# %% [markdown]
# * _*Al buscar la combinacion de parametros que haya devuelto el menor indice de **rmse** en la primera celda de codigo encuentro que la combinacion `0.601` y `0.01` de las mismas devolvieron el menor **rmse**.[Facebook-GitHub optimizacion de hiperparametros para Prophet](https://facebook.github.io/prophet/docs/diagnostics.html#hyperparameter-tuning).*_
#
#
# * _*Voy a probar distintas combinaciones de `rolling_window` y `horizon` para evaluar si estas presentan mejoras.*_
#
#
# * _*Quizas si se mantienen los parametros como fueron utilizadas en la [guia de Facebook](https://facebook.github.io/prophet/docs/diagnostics.html#hyperparameter-tuning) pueda probar mayores combinaciones de `rolling_window` y `horizon` dado que, utilizando la forma de la guia, la busqueda de mejoras tarda segundos a raiz de que ejecutan se **muchas menos** combinaciones.*_

# %% [markdown]
# #### *Re-entrenando/Evaluando modelo_1*

# %% [markdown]
# * _*Entreno modelo-hypertunned 1.*_

# %%
model_1= Prophet(interval_width=0.95, changepoint_prior_scale =  0.601000, seasonality_prior_scale = 0.01)

model_1.fit(semanal1)

prophet_dates = model_1.make_future_dataframe(periods=52, freq='W')
prophet_pred_1 = model_1.predict(prophet_dates)
prophet_pred_1[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds          yhat    yhat_lower    yhat_upper
# 0 2017-01-01  44468.889705  40193.806248  48801.574758
# 1 2017-01-08  44061.595107  39341.726700  48857.024246
# 2 2017-01-15  45903.349239  41163.484417  50474.189240
# 3 2017-01-22  48235.804911  44075.256963  52920.808399
# 4 2017-01-29  49351.931965  44931.429825  53731.177758

# %%
prophet_pred_2019_1 = prophet_pred_1[(prophet_pred_1.ds >= "2019-10-06") & (prophet_pred_1.ds <= "2019-12-29")]

prophet_pred_2019_1.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)


prophet_pred_2019_1.rename(columns={'ds':'fecha', "yhat":'cantidad_autos'}, inplace=True)


prophet_pred_2019_1 = prophet_pred_2019_1.set_index('fecha')

prophet_pred_2019_1
# Out:
#             cantidad_autos
# fecha
# 2019-10-06    38651.647594
# 2019-10-13    37997.475188
# 2019-10-20    38191.067264
# 2019-10-27    39216.835131
# 2019-11-03    40016.178757
# 2019-11-10    39659.982576
# 2019-11-17    38527.368995
# 2019-11-24    37992.420524
# 2019-12-01    38811.247603
# 2019-12-08    40034.986832
# 2019-12-15    39832.253401
# 2019-12-22    37467.090273
# 2019-12-29    34284.875863

# %%
plt.figure(figsize=(20,10))


plt.plot(prophet_pred_2019_1.index, prophet_pred_2019_1.cantidad_autos, lw = 2, label= "Prophet - 4to Trimestre-2019")
plt.plot(sarimax_pred_2019.index, sarimax_pred_2019.cantidad_autos, lw = 2.5, label='SARIMAX One-Step-Prediction', alpha=1, color="goldenrod")
plt.plot(ult_tri_2019.index, ult_tri_2019.cantidad_autos,'-.', lw = 4, label='Serie Observada (4to Trimestre 2019)', alpha=0.5, color="darkred")
plt.xlabel("\n Fecha", fontsize=18, color= "indigo")
plt.ylabel("\n Cantidad Autos", fontsize=18, color= "indigo", loc="top", rotation=0)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Prophet / SARIMAX / S.O \n", fontsize=25, color="k")
plt.legend(fontsize=15)


plt.show()


y_forecast_prophet=  prophet_pred_2019_1.cantidad_autos
y= ult_tri_2019.cantidad_autos

rmse_prophet = np.sqrt(metrics.mean_squared_error(y_forecast_prophet, y))
print("RMSE- Prophet: ", rmse_prophet)
print("RMSE- SARIMAX: ", rmse_sarimax_one)
# Out:
# RMSE- Prophet:  1585.4535544865303
# RMSE- SARIMAX:  67.08190224279655

# %% [markdown]
# #### *Re-entrenando/Evaluando modelo_2*

# %% [markdown]
# * _*Entreno modelo-hypertunned 2.*_

# %%
model_2= Prophet(interval_width=0.95, changepoint_prior_scale = 0.001,
                 seasonality_prior_scale = 0.01)

model_2.fit(semanal1)

prophet_dates = model_2.make_future_dataframe(periods=52, freq='W')
prophet_pred_2 = model_2.predict(prophet_dates)
prophet_pred_2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
#           ds          yhat    yhat_lower    yhat_upper
# 0 2017-01-01  47153.140520  41158.105349  53123.980222
# 1 2017-01-08  46549.358100  40948.483940  52338.285962
# 2 2017-01-15  48125.146145  42580.050441  53876.598135
# 3 2017-01-22  50260.820137  44945.752574  56318.650323
# 4 2017-01-29  51313.362819  45568.685577  56832.645607

# %%
prophet_pred_2019_2 = prophet_pred_2[(prophet_pred_2.ds >= "2019-10-06") & (prophet_pred_2.ds <= "2019-12-29")]

prophet_pred_2019_2.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)


prophet_pred_2019_2.rename(columns={'ds':'fecha', "yhat":'cantidad_autos'}, inplace=True)


prophet_pred_2019_2 = prophet_pred_2019_2.set_index('fecha')

prophet_pred_2019_2
# Out:
#             cantidad_autos
# fecha
# 2019-10-06    38639.636053
# 2019-10-13    38045.602162
# 2019-10-20    38215.032344
# 2019-10-27    39163.391540
# 2019-11-03    39919.893031
# 2019-11-10    39596.543188
# 2019-11-17    38514.396050
# 2019-11-24    37956.607744
# 2019-12-01    38666.447570
# 2019-12-08    39782.352374
# 2019-12-15    39560.401531
# 2019-12-22    37242.036174
# 2019-12-29    34048.638110

# %%
plt.figure(figsize=(20,10))


plt.plot(prophet_pred_2019_2.index, prophet_pred_2019_2.cantidad_autos, lw = 2, label= "Prophet - 4to Trimestre-2019")
plt.plot(sarimax_pred_2019.index, sarimax_pred_2019.cantidad_autos, lw = 2.5, label='SARIMAX One-Step-Prediction', alpha=1, color="goldenrod")
plt.plot(ult_tri_2019.index, ult_tri_2019.cantidad_autos,'-.', lw = 4, label='Serie Observada (4to Trimestre 2019)', alpha=0.5, color="darkred")
plt.xlabel("\n Fecha", fontsize=18, color= "indigo")
plt.ylabel("\n Cantidad Autos", fontsize=18, color= "indigo", loc="top", rotation=0)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Prophet / SARIMAX / S.O \n", fontsize=25, color="k")
plt.legend(fontsize=15)


plt.show()


y_forecast_prophet=  prophet_pred_2019_2.cantidad_autos
y= ult_tri_2019.cantidad_autos

rmse_prophet = np.sqrt(metrics.mean_squared_error(y_forecast_prophet, y))
print("RMSE- Prophet: ", rmse_prophet)
print("RMSE- SARIMAX: ", rmse_sarimax_one)
# Out:
# RMSE- Prophet:  1596.833704844555
# RMSE- SARIMAX:  67.08190224279655

# %% [markdown]
# * _*Se puede ver como, para ambas combinaciones, los resultados no demuestran mejoras en contraste a las implementaciones realizadas.*_
#
#
# * _*Voy a plantear unas combinaciones distintas en cuanto a `rolling_window`y `horizon` utilizando menos valores para los parametros a mejorar esperando asi, luego de probar varias veces, encontrar mejoras a la hora de re-modelar y evaluar.*_

# %% [markdown]
# #### *Combinaciones de Parametros 2*

# %%
param_grid = {  
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0]}

all_params_1 = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

cutoffs = pd.to_datetime(['2017-07-17', '2018-08-19', '2019-10-06'])

# %%
gs_prophet(all_params_1, Prophet, semanal1, cutoffs, 365, '90 days')
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C681CA05E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6834611F0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C681CA05E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A81FF70>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A551B50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6908A02B0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A56C9A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A539B80>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682AA0520>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A56C9A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A578B80>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A6A5E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A82CDC0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829FC6D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6908A02B0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A56C7C0>
# (    changepoint_prior_scale  seasonality_prior_scale           rmse
#  0                     0.001                     0.01    4419.599980
#  1                     0.001                     0.10    5957.452027
#  2                     0.001                     1.00   32030.356075
#  3                     0.001                    10.00  113875.394819
#  4                     0.010                     0.01    4440.937404
#  5                     0.010                     0.10    6243.486302
#  6                     0.010                     1.00   40784.118835
#  7                     0.010                    10.00  115200.798295
#  8                     0.100                     0.01    3260.243181
#  9                     0.100                     0.10    5345.855670
#  10                    0.100                     1.00   37040.952699
#  11                    0.100                    10.00  131946.057648
#  12                    0.500                     0.01    2598.357460
#  13                    0.500                     0.10    4938.356729
#  14                    0.500                     1.00   36992.897737
#  15                    0.500                    10.00  131928.692427,
#  changepoint_prior_scale       0.50000
#  seasonality_prior_scale       0.01000
#  rmse                       2598.35746
#  Name: 12, dtype: float64,
#  {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 0.01})

# %% [markdown]
# #### *Re-entrando/Evaluando modelo*

# %%
model_3= Prophet(interval_width=0.95, changepoint_prior_scale = 0.500000, seasonality_prior_scale = 0.010000)

model_3.fit(semanal1)

prophet_dates = model_3.make_future_dataframe(periods=52, freq='W')
prophet_pred_3 = model_3.predict(prophet_dates)
prophet_pred_3[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds          yhat    yhat_lower    yhat_upper
# 0 2017-01-01  44371.650425  40069.246999  49060.079048
# 1 2017-01-08  43987.974249  39516.786187  48597.505867
# 2 2017-01-15  45842.731105  41162.184102  50038.880873
# 3 2017-01-22  48179.470510  43396.196712  52949.054362
# 4 2017-01-29  49298.600390  44557.640029  53808.023004

# %%
prophet_pred_2019_3 = prophet_pred_3[(prophet_pred_3.ds >= "2019-10-06") & (prophet_pred_3.ds <= "2019-12-29")]

prophet_pred_2019_3.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)


prophet_pred_2019_3.rename(columns={'ds':'fecha', "yhat":'cantidad_autos'}, inplace=True)


prophet_pred_2019_3 = prophet_pred_2019_3.set_index('fecha')

prophet_pred_2019_3
# Out:
#             cantidad_autos
# fecha
# 2019-10-06    38657.186131
# 2019-10-13    38010.487388
# 2019-10-20    38209.057154
# 2019-10-27    39236.841562
# 2019-11-03    40037.573737
# 2019-11-10    39684.863225
# 2019-11-17    38557.309754
# 2019-11-24    38024.864032
# 2019-12-01    38840.294298
# 2019-12-08    40057.173482
# 2019-12-15    39852.027262
# 2019-12-22    37495.794049
# 2019-12-29    34332.959290

# %%
plt.figure(figsize=(20,10))


plt.plot(prophet_pred_2019_3.index, prophet_pred_2019_3.cantidad_autos, lw = 2, label= "Prophet - 4to Trimestre-2019")
plt.plot(sarimax_pred_2019.index, sarimax_pred_2019.cantidad_autos, lw = 2.5, label='SARIMAX One-Step-Prediction', alpha=1, color="goldenrod")
plt.plot(ult_tri_2019.index, ult_tri_2019.cantidad_autos,'-.', lw = 4, label='Serie Observada (4to Trimestre 2019)', alpha=0.5, color="darkred")
plt.xlabel("\n Fecha", fontsize=18, color= "indigo")
plt.ylabel("\n Cantidad Autos", fontsize=18, color= "indigo", loc="top", rotation=0)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Prophet / SARIMAX / S.O \n", fontsize=25, color="k")
plt.legend(fontsize=15)


plt.show()


y_forecast_prophet=  prophet_pred_2019_3.cantidad_autos
y= ult_tri_2019.cantidad_autos

rmse_prophet = np.sqrt(metrics.mean_squared_error(y_forecast_prophet, y))
print("RMSE- Prophet: ", rmse_prophet)
print("RMSE- SARIMAX: ", rmse_sarimax_one)
# Out:
# RMSE- Prophet:  1587.628029803266
# RMSE- SARIMAX:  67.08190224279655

# %% [markdown]
# #### *Combinaciones de Prametros 3*

# %%
param_grid = {  
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.351, 0.401, 0.5, 0.701, 0.801, 0.951, 1],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0]}

all_params_1 = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

cutoffs = pd.to_datetime(['2017-07-17', '2018-08-19', '2019-10-06'])

# %%
gs_prophet(all_params_1, Prophet, semanal1, cutoffs, 12, '365 days')
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A5B400>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C683459E20>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A3DC40>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A3D070>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A8715B0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A8620A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A4C71C0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C681D21DC0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB5C5B0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A55FD0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682AB9A90>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A55190>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A37F970>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829BC670>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A45820>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C6829E3F10>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB41460>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A79D30>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A88BA00>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C681D21DC0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A8718E0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A57F850>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A60490>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB689D0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A79D30>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A871730>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C681D21DC0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A37F7C0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A4C7F10>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A5B880>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A4C76A0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A79D30>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A3D070>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C681CA4520>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68BB68520>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A88BFD0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C68A4C7580>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C683459E20>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C682A5B8B0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x000002C683459E20>
# (    changepoint_prior_scale  seasonality_prior_scale          rmse
#  0                     0.001                     0.01  4.927680e+03
#  1                     0.001                     0.10  1.352981e+04
#  2                     0.001                     1.00  5.252111e+04
#  3                     0.001                    10.00  7.791955e+04
#  4                     0.010                     0.01  4.930539e+03
#  5                     0.010                     0.10  1.545574e+04
#  6                     0.010                     1.00  7.009971e+04
#  7                     0.010                    10.00  7.868755e+04
#  8                     0.100                     0.01  3.519674e+03
#  9                     0.100                     0.10  1.506385e+04
#  10                    0.100                     1.00  6.250168e+04
#  11                    0.100                    10.00  8.849548e+04
#  12                    0.351                     0.01  5.030797e+03
#  13                    0.351                     0.10  1.539092e+04
#  14                    0.351                     1.00  6.276772e+04
#  15                    0.351                    10.00  8.856713e+04
#  16                    0.401                     0.01  5.690662e+03
#  17                    0.401                     0.10  1.539530e+04
#  18                    0.401                     1.00  6.242342e+04
#  19                    0.401                    10.00  8.857047e+04
#  20                    0.500                     0.01  7.004185e+03
#  21                    0.500                     0.10  1.543177e+04
#  22                    0.500                     1.00  6.268907e+04
#  23                    0.500                    10.00  8.858811e+04
#  24                    0.701                     0.01  8.723968e+03
#  25                    0.701                     0.10  1.045980e+04
#  26                    0.701                     1.00  8.579350e+04
#  27                    0.701                    10.00  8.867128e+04
#  28                    0.801                     0.01  9.286468e+03
#  29                    0.801                     0.10  8.551792e+03
#  30                    0.801                     1.00  1.294436e+05
#  31                    0.801                    10.00  3.061202e+05
#  32                    0.951                     0.01  1.108487e+04
#  33                    0.951                     0.10  8.591136e+03
#  34                    0.951                     1.00  3.389701e+05
#  35                    0.951                    10.00  1.374028e+06
#  36                    1.000                     0.01  1.187181e+04
#  37                    1.000                     0.10  2.221859e+04
#  38                    1.000                     1.00  3.418895e+05
#  39                    1.000                    10.00  2.051364e+06,
#  changepoint_prior_scale       0.100000
#  seasonality_prior_scale       0.010000
#  rmse                       3519.674011
#  Name: 8, dtype: float64,
#  {'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 0.01})

# %% [markdown]
# #### *Re-entrando/Evaluando modelo*

# %%
model_4= Prophet(interval_width=0.95, changepoint_prior_scale = 0.05000, seasonality_prior_scale = 0.010000)

model_4.fit(semanal1)

prophet_dates = model_4.make_future_dataframe(periods=52, freq='W')
prophet_pred_4 = model_4.predict(prophet_dates)
prophet_pred_4[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds          yhat    yhat_lower    yhat_upper
# 0 2017-01-01  44512.862479  39512.228090  49467.775643
# 1 2017-01-08  44172.696364  38806.399912  49086.268186
# 2 2017-01-15  45990.824157  40788.850811  50668.746771
# 3 2017-01-22  48292.577214  43004.258352  53341.209499
# 4 2017-01-29  49440.202070  43968.507991  54561.031028

# %%
prophet_pred_2019_4 = prophet_pred_4[(prophet_pred_4.ds >= "2019-10-06") & (prophet_pred_4.ds <= "2019-12-29")]

prophet_pred_2019_4.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)


prophet_pred_2019_4.rename(columns={'ds':'fecha', "yhat":'cantidad_autos'}, inplace=True)


prophet_pred_2019_4 = prophet_pred_2019_4.set_index('fecha')

prophet_pred_2019_4
# Out:
#             cantidad_autos
# fecha
# 2019-10-06    38347.444087
# 2019-10-13    37747.062795
# 2019-10-20    37953.093982
# 2019-10-27    38955.957702
# 2019-11-03    39740.486543
# 2019-11-10    39406.279949
# 2019-11-17    38306.661958
# 2019-11-24    37760.141444
# 2019-12-01    38504.799855
# 2019-12-08    39643.694976
# 2019-12-15    39420.395122
# 2019-12-22    37115.612420
# 2019-12-29    34005.980687

# %%
plt.figure(figsize=(20,10))


plt.plot(prophet_pred_2019_4.index, prophet_pred_2019_4.cantidad_autos, lw = 2, label= "Prophet - 4to Trimestre-2019")
plt.plot(sarimax_pred_2019.index, sarimax_pred_2019.cantidad_autos, lw = 2.5, label='SARIMAX One-Step-Prediction', alpha=1, color="goldenrod")
plt.plot(ult_tri_2019.index, ult_tri_2019.cantidad_autos,'-.', lw = 4, label='Serie Observada (4to Trimestre 2019)', alpha=0.5, color="darkred")
plt.xlabel("\n Fecha", fontsize=18, color= "indigo")
plt.ylabel("\n Cantidad Autos", fontsize=18, color= "indigo", loc="top", rotation=0)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Prophet / SARIMAX / S.O \n", fontsize=25, color="k")
plt.legend(fontsize=15)


plt.show()


y_forecast_prophet=  prophet_pred_2019_4.cantidad_autos
y= ult_tri_2019.cantidad_autos

rmse_prophet = np.sqrt(metrics.mean_squared_error(y_forecast_prophet, y))
print("RMSE- Prophet: ", rmse_prophet)
print("RMSE- SARIMAX: ", rmse_sarimax_one)
# Out:
# RMSE- Prophet:  1605.1052656968448
# RMSE- SARIMAX:  67.08190224279655

# %% [markdown]
# * _*Por mas que se prueban distintas combinaciones no parece que las implementaciones aplicas a Prophet tengan mucho impacto. El mejor modelo devolvio un RMSE de 1587, mejor que el rmse de Prophet default (1628), pero el modelo creado en el proyecto anterior resulta ser mucho mejor que los probados aqui.*_
#
#
#
# * _*Siendo esa la conclusion, no intuyo que la prediccion del año 2020 de Prophet sea mejor que la de SARIMAX pero, ya que cree los modelos "mejorados" es cuestion de seleccionar las fechas a graficar de alguno de estos y observar.*_

# %% [markdown]
# ### Prediccion : Año 2020

# %% [markdown]
# #### *Prophet-default pred*
#
# * _*Las predicciones originales de Prophet*_

# %%
prophet_pred_2020 = prophet_pred[(prophet_pred.ds >= "2020-01-05") & (prophet_pred.ds <= "2020-10-04")]

prophet_pred_2020.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)


prophet_pred_2020.rename(columns={'ds':'fecha', "yhat":'cantidad_autos'}, inplace=True)


prophet_pred_2020 = prophet_pred_2020.set_index('fecha')

prophet_pred_2020
# Out:
#             cantidad_autos
# fecha
# 2020-01-05    31077.540800
# 2020-01-12    31918.916566
# 2020-01-19    34694.675764
# 2020-01-26    37021.694884
# 2020-02-02    37513.065352
# 2020-02-09    36657.200318
# 2020-02-16    35807.956481
# 2020-02-23    35710.540017
# 2020-03-01    36098.790947
# 2020-03-08    36395.807706
# 2020-03-15    36405.806043
# 2020-03-22    36272.701914
# 2020-03-29    36070.087515
# 2020-04-05    35708.298449
# 2020-04-12    35193.076713
# 2020-04-19    34728.954936
# 2020-04-26    34468.797140
# 2020-05-03    34309.639178
# 2020-05-10    34085.074051
# 2020-05-17    33874.802485
# 2020-05-24    33908.724414
# 2020-05-31    34123.737425
# 2020-06-07    34041.901692
# 2020-06-14    33322.239994
# 2020-06-21    32386.462920
# 2020-06-28    32217.649968
# 2020-07-05    33349.323148
# 2020-07-12    35147.503014
# 2020-07-19    36306.055308
# 2020-07-26    36102.563410
# 2020-08-02    35032.882375
# 2020-08-09    34145.328369
# 2020-08-16    33916.336510
# 2020-08-23    33984.448555
# 2020-08-30    33914.635430
# 2020-09-06    33870.234673
# 2020-09-13    34281.266949
# 2020-09-20    35019.333703
# 2020-09-27    35325.345471
# 2020-10-04    34753.053467

# %% [markdown]
# #### *Prophet-tunned pred*
#
# * _*Predicciones del mejor modelo de Prophet*_

# %%
prophet_pred_2020_1 = prophet_pred_1[(prophet_pred_1.ds >= "2020-01-05") & (prophet_pred_1.ds <= "2020-10-04")]

prophet_pred_2020_1.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)


prophet_pred_2020_1.rename(columns={'ds':'fecha', "yhat":'cantidad_autos'}, inplace=True)


prophet_pred_2020_1 = prophet_pred_2020_1.set_index('fecha')

prophet_pred_2020_1
# Out:
#             cantidad_autos
# fecha
# 2020-01-05    32564.442196
# 2020-01-12    33399.783721
# 2020-01-19    35789.750927
# 2020-01-26    37755.632662
# 2020-02-02    38178.802279
# 2020-02-09    37498.456683
# 2020-02-16    36845.671060
# 2020-02-23    36819.448852
# 2020-03-01    37175.999024
# 2020-03-08    37433.688280
# 2020-03-15    37449.282036
# 2020-03-22    37364.472685
# 2020-03-29    37245.197705
# 2020-04-05    37002.239373
# 2020-04-12    36622.263421
# 2020-04-19    36270.787949
# 2020-04-26    36084.735874
# 2020-05-03    35987.475530
# 2020-05-10    35835.139666
# 2020-05-17    35678.144759
# 2020-05-24    35699.856366
# 2020-05-31    35859.996230
# 2020-06-07    35783.204430
# 2020-06-14    35194.068626
# 2020-06-21    34425.432486
# 2020-06-28    34266.096997
# 2020-07-05    35149.162447
# 2020-07-12    36568.309147
# 2020-07-19    37472.691745
# 2020-07-26    37280.594302
# 2020-08-02    36393.311876
# 2020-08-09    35656.587326
# 2020-08-16    35451.317657
# 2020-08-23    35481.479068
# 2020-08-30    35396.265460
# 2020-09-06    35332.246599
# 2020-09-13    35637.970130
# 2020-09-20    36202.468588
# 2020-09-27    36403.336838
# 2020-10-04    35881.314179

# %% [markdown]
# #### *Prophet-tunned pred 2*
#
# * _*Predicciones del segundo mejor modelo de Prophet.*_

# %%
prophet_pred_2020_2 = prophet_pred_2[(prophet_pred_2.ds >= "2020-01-05") & (prophet_pred_2.ds <= "2020-10-04")]

prophet_pred_2020_2.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)


prophet_pred_2020_2.rename(columns={'ds':'fecha', "yhat":'cantidad_autos'}, inplace=True)


prophet_pred_2020_2 = prophet_pred_2020_2.set_index('fecha')

prophet_pred_2020_2
# Out:
#             cantidad_autos
# fecha
# 2020-01-05    32157.348738
# 2020-01-12    32688.423072
# 2020-01-19    34771.672304
# 2020-01-26    36543.767852
# 2020-02-02    36897.606075
# 2020-02-09    36202.169299
# 2020-02-16    35522.165751
# 2020-02-23    35443.543175
# 2020-03-01    35741.153814
# 2020-03-08    35942.368360
# 2020-03-15    35898.211499
# 2020-03-22    35752.958829
# 2020-03-29    35589.134139
# 2020-04-05    35324.848365
# 2020-04-12    34929.358359
# 2020-04-19    34545.777458
# 2020-04-26    34313.465745
# 2020-05-03    34179.503240
# 2020-05-10    34010.131691
# 2020-05-17    33835.438176
# 2020-05-24    33817.901180
# 2020-05-31    33934.931791
# 2020-06-07    33857.027216
# 2020-06-14    33324.428368
# 2020-06-21    32619.464738
# 2020-06-28    32454.687088
# 2020-07-05    33241.505520
# 2020-07-12    34535.657020
# 2020-07-19    35373.258426
# 2020-07-26    35202.002807
# 2020-08-02    34379.105138
# 2020-08-09    33692.443688
# 2020-08-16    33508.776004
# 2020-08-23    33552.444031
# 2020-08-30    33478.344407
# 2020-09-06    33400.664617
# 2020-09-13    33659.706482
# 2020-09-20    34184.496255
# 2020-09-27    34406.999729
# 2020-10-04    33966.857543

# %% [markdown]
# #### *Graficando y Evaluando*

# %%
plt.figure(figsize=(20,10))

plt.plot(benchmark, label= 'SARIMAX (Benchmark) Prediccion-2020')
plt.plot(prophet_pred_2020.index, prophet_pred_2020.cantidad_autos, lw = 2, label= "Prophet - Año 2020 ")
plt.plot(prophet_pred_2020_1.index, prophet_pred_2020_1.cantidad_autos, lw = 2, label= "Prophet(Hypertunned/Best Model) - Año 2020 ")
plt.plot(prophet_pred_2020_2.index, prophet_pred_2020_2.cantidad_autos, lw = 2, label= "Prophet(Hypertunned/2nd Best Model) - Año 2020 ")
plt.plot(semanal_2020.index, semanal_2020.cantidad_autos, lw = 4, label= 'Serie observada (Año 2020)')
plt.xlabel("\n Fecha", fontsize=18, color= "indigo")
plt.ylabel("\n Cantidad Autos", fontsize=18, color= "indigo", loc="top", rotation=0)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Prophet / Benchmark / S.O \n", fontsize=25, color="k")
plt.legend(fontsize=15)

plt.show()



y_forecast_prophet_2020=  prophet_pred_2020.cantidad_autos
y_forecast_prophet_2020_1=  prophet_pred_2020_1.cantidad_autos
y_forecast_prophet_2020_2=  prophet_pred_2020_2.cantidad_autos
y= semanal_2020.cantidad_autos

rmse_prophet_2020 = np.sqrt(metrics.mean_squared_error(y_forecast_prophet_2020, y))
rmse_prophet_2020_1 = np.sqrt(metrics.mean_squared_error(y_forecast_prophet_2020_1, y))
rmse_prophet_2020_2 = np.sqrt(metrics.mean_squared_error(y_forecast_prophet_2020_2, y))
print("RMSE- Prophet: ", rmse_prophet_2020_1)
print("RMSE- Prophet(Hypertunned/Best Model): ", rmse_prophet_2020_1)
print("RMSE- Prophet(Hypertunned/2nd Best Model): ", rmse_prophet_2020_2)
print("RMSE- SARIMAX(Benchmark): ", rmse_benchmark)
# Out:
# RMSE- Prophet:  20485.661829840847
# RMSE- Prophet(Hypertunned/Best Model):  20485.661829840847
# RMSE- Prophet(Hypertunned/2nd Best Model):  18878.408761121238
# RMSE- SARIMAX(Benchmark):  18861.797260273714

# %% [markdown]
# * _*Sorprendentemente la mejor prediccion de Prophet(model_1) la cual otorgo el mejor resultado rmse, devuelve un peor resultado en cuanto a la prediccion del año 2020 confrontado con SARIMAX y tambien, en cuanto al segundo mejor modelo de Prophet(model_2). Este mismo devuelve un RMSE mucho mas aproximado al de SARIMAX en cuanto a la prediccion de 2020.2*_
#
#
# * _*La prediccion de SARIMAX, por muy poco, es mejor que la de Prophet (ambas siendo muy malas, pero debido al caso especial de la pandemia).*_
#
#
# * _*Las primeras prediccions de Prophet se parecen mucho antes y despues del Hypertunnig de los parametros. Ninguna denota mejoras notables por sobre el modelo de SARIMAX.*_
#
#
# * _*El modelo creado en el [Proyecto 3](https://github.com/MiltonDeMarte/Series-de-Tiempo.git) sigue siendo el que otorga mejores resultados, en todas las predicciones echas y requeridas por el cliente. Si bien Prophet no presente mejoras notables(tampoco por sobre los otros modelos del proyecto anterior) creo que es cuestion de seguir profundizando en su funcionalidad explorando mejor sus implementaciones y distintos componentes.*_

# %% [markdown]
# ## **Conclusiones Finales:**

# %% [markdown]
# * _*Si bien se planteo un proyecto corto, al momento de utilizar una nueva libreria no vista en clase priorice dedicarle el tiempo necesario a entender que es lo que hace cada "parte" utilizada de esa libreria en este proyecto.*_
#
#
# * _*Inicialmente, este proyecto se inicio con la intencion de encontrar un modelo de Prophet que consigna mejorar la prediccion de SARIMAX (aunque sea por 1 en metrica RMSE) pero esto no pudo ser dado que, tras muchos intentos los 4 modelos de Prophet creados no consiguieron mejorar el resultado obtenido en el proyecto anterior.*_
#
#
# * _*Trabajar con los datos de este año (2020) resulto intersante a la hora de poder graficar un evento que , de antemano, ya conocia. Poder ver el contraste de tal evento impredecible en los datos resulto de mucho interes y da lugar a entender que; En el mundo todo puede cambiar en cuestion de segundos y estar preparado para eso, o lo mas cercano, es la mejor estrategia.¿Como? Solo a travez de los datos, pero siempre se necesita un evento(como este-Covid 19) para poder entender que hay que prepararse para un posible proximo evento "similar".*_
#
#
# **Implementaciones a considerar:**
#
# * _*En un principio, me propuse aplicar otro modelo mas al proyecto (LSTM). Esto resulto bastante dificil al momento de su aplicacion al querer hacerlo sin conocimiento previo **fuerte** de como funcionan las redes neuronales. Entonces, por motivos de practicidad decidi dejar el modelo de redes fuera de este proyecto y tomarlo ya como un "desafio" personal para luego, volver sobre este proyecto pudiendo asi implementar LSTM.*_
#
#
# * _*Pretendo seguir estudiando, por mi cuenta por el momento, y profundizando en las implementaciones de redes dado que creo que estas pueden mejorar la prediccion de SARIMAX.*_
#
#
# * _*Estoy abierto a recibir cualquier tipo de informacion que pueda ayudar en mi proceso de mejorar mi conocimiento y rendimiento en redes.*_
